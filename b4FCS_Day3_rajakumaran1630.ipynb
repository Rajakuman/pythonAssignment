# %% [markdown]
# # **Assignment 2**
# **Question no:1**
# WAP for taking one number a input and then using if elif else concept, assign a grade
# to the input number from
# A,B,C,D,E, Fail
#
# **A=90 to 100**
# **B=80 to 89**
# **C=70 to 79**
# **D=60 to 69**
# **E=50 to 59**
# **Fail= less then 50**
#
# **if user entered more then 100, it is no grade**
#
# In a formatted report card Example :
# Input - 97
# Output -
#          |--------|
#          |    A   |
#          |--------|

# %%
out="A";
in_value=input("Enter the input mark:")
print("Input - ",in_value)
in_value=int(in_value)

if in_value>=90 and in_value<=100:
  out="A"
elif in_value>=80 and in_value<=89:
  out="B"
elif in_value>=70 and in_value<=79:
  out="C"
elif in_value>=60 and in_value<=69:
  out="D"
elif in_value>=50 and in_value<=59:
  out="E"
elif  in_value<=49:
  out="Fail"
elif in_value>=101:
  out="NO GRADE"

if out=="A" or  out=="B" or  out=="C" or  out=="D" or  out=="E" : 
  print("Output - |-------------|")
  print("         |      "+out+"      |")
  print("         |-------------|")

if out=="NO GRADE": 
  print("Output - |--------------------|")
  print("         |      NO GRADE      |")
  print("         |--------------------|")



if out=="Fail": 
  print("Output - |---------------|")
  print("         |      Fail     |")
  print("         |---------------|")
# Out:
# Enter the input mark:92
# Input -  92
# Output - |-------------|
#          |      A      |
#          |-------------|

# %% [markdown]
# # **Question no 2:**
# Guessing Team India Score in 20-20 Cricket -
# WAP gives you a random score of Team India in a cricket match, and a player has to
# guess the score given by computer in between 1 to 250. The rules are:
#
# If a player's guess is less than 1 or greater than 250, say "Reduce your expectation for 20-20
# Cricket"
#
#
# On a player's input, if their score guess is
# a. within 10 of the number, return "**Close By, you are True Indian Fan!** "
# b. further than 10 away from the number, return "**You are not a true Indian Fan!** :P "

# %%
from numpy import random

in_score=input("Enter Team guess the score:")
in_score=int(in_score)
random_score = random.randint(1,250)
diff=random_score-in_score
print("input score:",in_score)
print("Random score:",random_score)
print("Differnece:",diff)

if diff<=10 and diff>=-10:
  print("Close By, you are True Indian Fan!")
else:
  print("You are not a true Indian Fan! :P")
# Out:
# Enter Team guess the score:150
# input score: 150
# Random score: 2
# Differnece: -148
# You are not a true Indian Fan! :P

# %% [markdown]
# # **Question 3:**
# Roy wants to change his profile picture on Facebook. Now Facebook has some
# restrictions over the dimension of pictures that we can upload.
#
# Minimum dimension of the picture can be L x L, where L is the length of the side of the square.
#
# Now Roy has N photos of various dimensions.
#
# Dimension of a photo is denoted as W x H
#
# where W - width of the photo and H - Height of the photo
#
# **When any photo is uploaded following events may occur:**
#
# [1] If any of the width or height is less than L, the user is prompted to upload another one. Print "**UPLOAD ANOTHER**" in this case.
#
# [2] If width and height, both are large enough and
#
# (a) if the photo is already square then it is accepted. Print "**ACCEPTED**" in this case.
#
# (b) else the user is prompted to crop it. Print "**CROP IT**" in this case. (quotes are only for clarification)
# Given L, N, W and H as input, print appropriate text as output.

# %%
import os  
import sys 

# First line contains 
# L=input("First Line")
# N=input("No of Photos")

l=input("Enter minimum dimension of the picture:")
l=int(l)
if l>=10001 or l<1 :
  print("min and max dimension size between 1 and 10000")
  print("Your are entered size is:",l)
  quit()
  sys.exit()
  os._exit(os.EX_OK) 

n=input("No of photos:")
n=int(n)
if l>=1001 or l<1 :
  print("No of phots max 1000")
  quit()
  sys.exit()
  os._exit(os.EX_OK) 


for x in range(n):
# Following N lines each contains single space separated integers are W and H.
  with_height=input("Enter width and height of photo:")
  str_spt=with_height.split()
  w=str_spt[0]
  h=str_spt[1]
  w=int(w)
  h=int(h)
  if w<=l or h<=l:
    print("UPLOAD ANOTHER")
  elif (w==l or h==l) or (w==h):
    print("ACCEPTED")
  else:
    print("CROP IT")
# Out:
# Enter minimum dimension of the picture:20
# No of photos:2
# Enter width and height of photo:21 21
# ACCEPTED
# Enter width and height of photo:23 23
# ACCEPTED

# %% [markdown]
# # **Question 4:**
# Ankit is in a maze. The command center sent him a string which decodes to
# come out from the maze.
#
# ➔ He is initially at (0, 0).
#
# ➔ String contains L, R, U, D denoting left, right, up and down.
#
# ➔ In each command he will traverse 1 unit distance in the respective direction.
#
# ➔ For example if he is at (2, 0) and the command is L he will go to (1, 0).
#
# ➔ You guys just need to make the flow of the logic which updates the position after taking
#
# input from our side:  L, R, U, D

# %%
x=0
y=0
str_values=input("enter the maze")
str_spts=str_values.split();
for items in (str_spts):
  item=items.replace(",","")
  item=item.strip()
  if item=="L":
    x=x-1;
  elif item=="D":
    y=y-1;
  elif item=="U":
    y=y+1;
  elif item=="R":
    x=x+1;

print("(",x,y,")")
# Out:
# enter the mazeL D R R U U
# ( 1 1 )
